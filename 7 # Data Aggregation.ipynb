# %% [markdown]
# <h1>Data Aggregation</h1>

# %% [raw]
# Data Aggregation refers to identifying data satisfying a condition.
#
# It helps in studying one or more aggregated groups together.

# %% [markdown]
# <h3>Applying Filter To a DataFrame</h3>

# %%
import pandas as pd

# %%
orders = pd.read_excel("Superstore.xls")

# %%
orders.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
orders[orders.Sales>=500].head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#     Customer Name   Segment        Country             City  ... Postal Code  \
# 1     Claire Gute  Consumer  United States        Henderson  ...       42420
# 3  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
#
#    Region       Product ID   Category Sub-Category  \
# 1   South  FUR-CH-10000454  Furniture       Chairs
# 3   South  FUR-TA-10000577  Furniture       Tables
#
#                                         Product Name     Sales  Quantity  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
#
#    Discount   Profit
# 1      0.00  219.582
# 3      0.45 -383.031
#
# [2 rows x 21 columns]

# %%
orders[orders['Ship Mode'] == 'First Class'].head(2)
# Out:
#     Row ID        Order ID Order Date  Ship Date    Ship Mode Customer ID  \
# 35      36  CA-2016-117590 2016-12-08 2016-12-10  First Class    GH-14485
# 36      37  CA-2016-117590 2016-12-08 2016-12-10  First Class    GH-14485
#
#    Customer Name    Segment        Country        City  ... Postal Code  \
# 35     Gene Hale  Corporate  United States  Richardson  ...       75080
# 36     Gene Hale  Corporate  United States  Richardson  ...       75080
#
#      Region       Product ID    Category Sub-Category  \
# 35  Central  TEC-PH-10004977  Technology       Phones
# 36  Central  FUR-FU-10003664   Furniture  Furnishings
#
#                                          Product Name     Sales  Quantity  \
# 35                                        GE 30524EE4  1097.544         7
# 36  Electrix Architect's Clamp-On Swing Arm Lamp, ...   190.920         5
#
#     Discount    Profit
# 35       0.2  123.4737
# 36       0.6 -147.9630
#
# [2 rows x 21 columns]

# %%
orders[orders['Ship Mode'] != 'First Class'].head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
orders[(orders['Ship Mode'] == 'First Class') & (orders['Sub-Category'] == 'Chairs')].head(2)
# Out:
#      Row ID        Order ID Order Date  Ship Date    Ship Mode Customer ID  \
# 57       58  CA-2016-111682 2016-06-17 2016-06-18  First Class    TB-21055
# 294     295  CA-2014-111451 2014-12-26 2014-12-28  First Class    KL-16555
#
#        Customer Name    Segment        Country              City  ...  \
# 57   Ted Butterfield   Consumer  United States              Troy  ...
# 294    Kelly Lampkin  Corporate  United States  Colorado Springs  ...
#
#     Postal Code  Region       Product ID   Category Sub-Category  \
# 57        12180    East  FUR-CH-10003968  Furniture       Chairs
# 294       80906    West  FUR-CH-10001891  Furniture       Chairs
#
#                            Product Name    Sales  Quantity  Discount   Profit
# 57             Novimex Turbo Task Chair  319.410         5       0.1   7.0980
# 294  Global Deluxe Office Fabric Chairs  230.352         3       0.2  20.1558
#
# [2 rows x 21 columns]

# %%
orders[(orders['Ship Mode'] == 'First Class') | (orders['Sub-Category'] == 'Chairs')].head(2)
# Out:
#     Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 1        2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 23      24  US-2017-156909 2017-07-16 2017-07-18  Second Class    SF-20065
#
#       Customer Name   Segment        Country          City  ... Postal Code  \
# 1       Claire Gute  Consumer  United States     Henderson  ...       42420
# 23  Sandra Flanagan  Consumer  United States  Philadelphia  ...       19140
#
#     Region       Product ID   Category Sub-Category  \
# 1    South  FUR-CH-10000454  Furniture       Chairs
# 23    East  FUR-CH-10002774  Furniture       Chairs
#
#                                          Product Name    Sales  Quantity  \
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940         3
# 23                 Global Deluxe Stacking Chair, Gray   71.372         2
#
#     Discount    Profit
# 1        0.0  219.5820
# 23       0.3   -1.0196
#
# [2 rows x 21 columns]

# %%
orders[orders['Sub-Category'].isin(['Chairs','Bookcases'])].head(5)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1        2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 23      24  US-2017-156909 2017-07-16 2017-07-18    Second Class    SF-20065
# 27      28  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 38      39  CA-2015-117415 2015-12-27 2015-12-31  Standard Class    SN-20710
#
#       Customer Name      Segment        Country          City  ...  \
# 0       Claire Gute     Consumer  United States     Henderson  ...
# 1       Claire Gute     Consumer  United States     Henderson  ...
# 23  Sandra Flanagan     Consumer  United States  Philadelphia  ...
# 27  Tracy Blumstein     Consumer  United States  Philadelphia  ...
# 38     Steve Nguyen  Home Office  United States       Houston  ...
#
#    Postal Code   Region       Product ID   Category Sub-Category  \
# 0        42420    South  FUR-BO-10001798  Furniture    Bookcases
# 1        42420    South  FUR-CH-10000454  Furniture       Chairs
# 23       19140     East  FUR-CH-10002774  Furniture       Chairs
# 27       19140     East  FUR-BO-10004834  Furniture    Bookcases
# 38       77041  Central  FUR-BO-10002545  Furniture    Bookcases
#
#                                          Product Name      Sales  Quantity  \
# 0                   Bush Somerset Collection Bookcase   261.9600         2
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 23                 Global Deluxe Stacking Chair, Gray    71.3720         2
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300         7
# 38  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...   532.3992         3
#
#     Discount     Profit
# 0       0.00    41.9136
# 1       0.00   219.5820
# 23      0.30    -1.0196
# 27      0.50 -1665.0522
# 38      0.32   -46.9764
#
# [5 rows x 21 columns]

# %% [markdown]
# <h4>Transforming Data</h4>

# %%
import numpy as np
df = pd.DataFrame({'temp':pd.Series(28 + 10*np.random.randn(10)),
                   'rain':pd.Series(100 + 50*np.random.randn(10)),
                   'location':list('AAAAABBBBB')
})
print(df.head())
# Out:
#         temp        rain location
# 0  18.579499  105.505663        A
# 1  17.088143  102.765615        A
# 2  19.004626  121.409033        A
# 3  30.844484   93.514056        A
# 4  25.392211  198.961327        A

# %% [raw]
# The below code replaces location names 'A' with 'Hyderabad' and 'B' with 'Mumbai'.

# %%
replacements = {
'location': {'A':'Hyderabad', 'B':'Mumbai'}
}
df = df.replace(replacements, regex=True)
print(df)
# Out:
#         temp        rain   location
# 0  18.579499  105.505663  Hyderabad
# 1  17.088143  102.765615  Hyderabad
# 2  19.004626  121.409033  Hyderabad
# 3  30.844484   93.514056  Hyderabad
# 4  25.392211  198.961327  Hyderabad
# 5  28.389312  140.892599     Mumbai
# 6  23.904900   80.910544     Mumbai
# 7  27.275205   40.239290     Mumbai
# 8  22.303856   72.539454     Mumbai
# 9  30.329252   45.029866     Mumbai

# %% [raw]
# It is also possible to filter rows, based on a column strings with a specific pattern and modify them.

# %%
df.location.str.contains('umb')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: location, dtype: bool

# %%
mumbai_data = df.loc[df.location.str.contains('umb'),:]
print(mumbai_data.head(2))
# Out:
#         temp        rain location
# 5  28.389312  140.892599   Mumbai
# 6  23.904900   80.910544   Mumbai

# %% [markdown]
# <h4>Grouping Data</h4>

# %% [raw]
# groupby method can be used to group data and perform various function on each group.

# %%
regions = df.groupby('location')
print(regions.mean())
# Out:
#                 temp        rain
# location
# Hyderabad  22.181793  124.431139
# Mumbai     26.440505   75.922351
